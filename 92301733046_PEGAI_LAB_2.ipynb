# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a361a2e6-3191-45f7-ad95-b217c2b214c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a361a2e6-3191-45f7-ad95-b217c2b214c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install -q google-genai pandas matplotlib seaborn

# %%
import pandas as pd
import numpy as np

from google import genai
from google.genai import types

# %%
GEMINI_API_KEY = "AQ.Ab8RN6KnvXBismGM86FOtUHy8_Eiq1lO1QIqDJYUjwIOAx2mZw"

# %%
client = genai.Client(api_key=GEMINI_API_KEY)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-d3edfc4b-7241-440f-a64c-8c980e117f65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3edfc4b-7241-440f-a64c-8c980e117f65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Titanic-Dataset.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
def ask_gemini(prompt):

    response = client.models.generate_content(
        model="gemini-3.5-flash-lite",
        contents=prompt,
        config=types.GenerateContentConfig(
            temperature=0.2
        )
    )

    return response.text

# %%
prompt = """
Write Python pandas code to display the first five rows of dataframe df.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df.head()
# ```

# %%
prompt = """
Write Python code to display dataframe information.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df.info()
# ```

# %%
prompt = """
Write pandas code to find missing values in dataframe df.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df.isnull().sum()
# ```

# %%
prompt = """
Write pandas code to calculate percentage of missing values.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df.isnull().mean() * 100
# ```

# %%
prompt = """
Find duplicate rows in dataframe df.
Only return Python code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df[df.duplicated()]
# ```

# %%
prompt = """
Remove duplicate rows from dataframe df.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df = df.drop_duplicates()
# ```

# %%
prompt = """
Fill numerical missing values using mean.
Only return pandas code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df.fillna(df.mean(numeric_only=True), inplace=True)
# ```

# %%
prompt = """
Fill categorical missing values using mode.
Only return pandas code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df[categorical_cols] = df[categorical_cols].fillna(df[categorical_cols].mode().iloc[0])
# ```

# %%
prompt = """
Rename all dataframe columns to lowercase.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df.columns = df.columns.str.lower()
# ```

# %%
prompt = """
Remove extra spaces from string columns.
Only return pandas code.
"""
print(ask_gemini(prompt))
# Out:
# ```python
# df[df.select_dtypes(include=["object", "string"]).columns] = df.select_dtypes(
#     include=["object", "string"]
# ).apply(lambda x: x.str.replace(r"\s+", " ", regex=True).str.strip())
# ```

# %%
prompt = """
Show dataframe shape.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df.shape
# ```

# %%
prompt = """
Generate summary statistics of dataframe df.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df.describe()
# ```

# %%
prompt = """
Detect outliers using IQR.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# import numpy as np
#
#
# def detect_outliers_iqr(data):
#     data = np.asarray(data)
#     q1 = np.percentile(data, 25)
#     q3 = np.percentile(data, 75)
#     iqr = q3 - q1
#     lower_bound = q1 - 1.5 * iqr
#     upper_bound = q3 + 1.5 * iqr
#     return data[(data < lower_bound) | (data > upper_bound)]
# ```

# %%
prompt = """
Remove outliers using IQR method.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# import pandas as pd
#
#
# def remove_outliers_iqr(df, columns):
#     df_clean = df.copy()
#     for col in columns:
#         Q1 = df_clean[col].quantile(0.25)
#         Q3 = df_clean[col].quantile(0.75)
#         IQR = Q3 - Q1
#         lower_bound = Q1 - 1.5 * IQR
#         upper_bound = Q3 + 1.5 * IQR
#         df_clean = df_clean[
#             (df_clean[col] >= lower_bound) & (df_clean[col] <= upper_bound)
#         ]
#     return df_clean
# ```

# %%
prompt = """
Convert categorical variables into dummy variables.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# import pandas as pd
#
# # Assuming `df` is your DataFrame and `categorical_cols` is a list of categorical column names
# df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
# ```

# %%
prompt = """
Display column data types.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```sql
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_name = 'your_table_name';
# ```

# %%
prompt = """
Count unique values in each column.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df.nunique()
# ```

# %%
prompt = """
Drop rows with more than 50 percent missing values.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df = df.dropna(thresh=len(df.columns) / 2)
# ```

# %%
prompt = """
Save cleaned dataframe as cleaned_titanic.csv.
Only return code.
"""

print(ask_gemini(prompt))
# Out:
# ```python
# df.to_csv("cleaned_titanic.csv", index=False)
# ```

# %%
prompt = """
Generate a short summary describing the cleaning steps performed.
"""

print(ask_gemini(prompt))
# Out:
# It looks like you forgot to include the details!
#
# Please provide the text, list, or description of the cleaning steps performed, and I will gladly generate a concise summary for you.

# %%
df.to_csv("cleaned_titanic.csv", index=False)
